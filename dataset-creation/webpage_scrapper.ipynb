# %% [markdown]
# # Webpage scrapper

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %% [markdown]
# # Tranco ranking
#
# We use the Tranco list* [1] generated on 13 December 2024, ...
# * Available at https://tranco-list.eu/list/KJ58W.

# %%
df_url = pd.read_csv('data/top-1m.csv', header=None, names=['rank', 'url'])
df_url = df_url.drop('rank', axis=1)

# %%
df_url
# Out:
#                          url
# 0                 google.com
# 1              microsoft.com
# 2                    mail.ru
# 3               facebook.com
# 4                    dzen.ru
# ...                      ...
# 999995  southhillpark.org.uk
# 999996           huntkey.com
# 999997   thecollectivity.org
# 999998             jpxzy.top
# 999999  lacartadelabolsa.com
#
# [1000000 rows x 1 columns]

# %%
def get_website_visual(url,filepath, mobile=False):
    try :
        chrome_options = Options()
        chrome_options.add_argument("--headless=new")
        chrome_options.add_argument("--mute-audio")
        chrome_options.add_argument('--hide-scrollbars')
        chrome_options.add_argument('--start-maximized')
        chrome_options.add_argument('--start-fullscreen')
        # chrome_options.add_argument("--window-size=1024,768")
        chrome_options.add_extension('extension/no-cookie.crx')

        if mobile:
            chrome_options.add_argument('--user-agent=Mozilla/5.0 (iPhone; CPU iPhone OS 17_7 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/131.0.6778.134 Mobile/15E148 Safari/604.1')
            chrome_options.add_argument("--window-size=393,873")

        driver = webdriver.Chrome(options=chrome_options)
        driver.get("http://"+url)
        driver.save_screenshot(filepath)

        print("Screenshot saved as: "+filepath)
    except Exception as e:
        print("error")
    finally:
        driver.quit()

get_website_visual(df_url['url'][6],"output/output.png", mobile=True)
# Out:
# error

# %%
for i in range (1010):
    filepath_desktop = 'output/desktop/'+df_url['url'][i].replace(".", "_")+'.png'
    filepath_mobile = 'output/mobile/'+df_url['url'][i].replace(".", "_")+'.png'
    get_website_visual(df_url['url'][i], filepath_desktop)
    get_website_visual(df_url['url'][i], filepath_mobile, mobile=True)
    print(i)
# Out:
# Screenshot saved as: output/desktop/google_com.png
# Screenshot saved as: output/mobile/google_com.png
# 0
# Screenshot saved as: output/desktop/microsoft_com.png
# Screenshot saved as: output/mobile/microsoft_com.png
# 1
# Screenshot saved as: output/desktop/mail_ru.png
# Screenshot saved as: output/mobile/mail_ru.png
# 2
# Screenshot saved as: output/desktop/facebook_com.png
# Screenshot saved as: output/mobile/facebook_com.png
# 3
# Screenshot saved as: output/desktop/dzen_ru.png
# Screenshot saved as: output/mobile/dzen_ru.png
# 4
# Screenshot saved as: output/desktop/apple_com.png
# Screenshot saved as: output/mobile/apple_com.png
# 5
# error
# error
# 6
# Screenshot saved as: output/desktop/amazonaws_com.png
# Screenshot saved as: output/mobile/amazonaws_com.png
# 7
# Screenshot saved as: output/desktop/youtube_com.png
# Screenshot saved as: output/mobile/youtube_com.png
# 8
# Screenshot saved as: output/desktop/googleapis_com.png
# Screenshot saved as: output/mobile/googleapis_com.png
# 9
# error
# error
# 10
# Screenshot saved as: output/desktop/twitter_com.png
# Screenshot saved as: output/mobile/twitter_com.png
# 11
# error
# error
# 12
# Screenshot saved as: output/desktop/cloudflare_com.png
# Screenshot saved as: output/mobile/cloudflare_com.png
# 13
# Screenshot saved as: output/desktop/instagram_com.png
# Screenshot saved as: output/mobile/instagram_com.png
# 14
# Screenshot saved as: output/desktop/azure_com.png
# Screenshot saved as: output/mobile/azure_com.png
# 15
# Screenshot saved as: output/desktop/gstatic_com.png
# Screenshot saved as: output/mobile/gstatic_com.png
# 16
# Screenshot saved as: output/desktop/office_com.png
# Screenshot saved as: output/mobile/office_com.png
# 17
# Screenshot saved as: output/desktop/linkedin_com.png
# Screenshot saved as: output/mobile/linkedin_com.png
# 18
# error
# error
# 19
# Screenshot saved as: output/desktop/live_com.png
# Screenshot saved as: output/mobile/live_com.png
# 20
# error
# error
# 21
# Screenshot saved as: output/desktop/googletagmanager_com.png
# Screenshot saved as: output/mobile/googletagmanager_com.png
# 22
# Screenshot saved as: output/desktop/googlevideo_com.png
# Screenshot saved as: output/mobile/googlevideo_com.png
# 23
# Screenshot saved as: output/desktop/amazon_com.png
# Screenshot saved as: output/mobile/amazon_com.png
# 24
# error
# error
# 25
# error
# error
# 26
# Screenshot saved as: output/desktop/fbcdn_net.png
# Screenshot saved as: output/mobile/fbcdn_net.png
# 27
# Screenshot saved as: output/desktop/doubleclick_net.png
# Screenshot saved as: output/mobile/doubleclick_net.png
# 28
# Screenshot saved as: output/desktop/wikipedia_org.png
# Screenshot saved as: output/mobile/wikipedia_org.png
# 29
# Screenshot saved as: output/desktop/googleusercontent_com.png
# Screenshot saved as: output/mobile/googleusercontent_com.png
# 30
# error
# error
# 31
# Screenshot saved as: output/desktop/bing_com.png
# Screenshot saved as: output/mobile/bing_com.png
# 32
# error
# error
# 33
# error
# error
# 34
# Screenshot saved as: output/desktop/googlesyndication_com.png
# Screenshot saved as: output/mobile/googlesyndication_com.png
# 35
# Screenshot saved as: output/desktop/wordpress_org.png
# Screenshot saved as: output/mobile/wordpress_org.png
# 36
# error
# error
# 37
# error
# error
# 38
# Screenshot saved as: output/desktop/workers_dev.png
# Screenshot saved as: output/mobile/workers_dev.png
# 39
# Screenshot saved as: output/desktop/fastly_net.png
# Screenshot saved as: output/mobile/fastly_net.png
# 40
# Screenshot saved as: output/desktop/github_com.png
# Screenshot saved as: output/mobile/github_com.png
# 41
# Screenshot saved as: output/desktop/youtu_be.png
# Screenshot saved as: output/mobile/youtu_be.png
# 42
# Screenshot saved as: output/desktop/icloud_com.png
# Screenshot saved as: output/mobile/icloud_com.png
# 43
# error
# error
# 44
# error
# error
# 45
# error
# error
# 46
# Screenshot saved as: output/desktop/sharepoint_com.png
# Screenshot saved as: output/mobile/sharepoint_com.png
# 47
# Screenshot saved as: output/desktop/netflix_com.png
# Screenshot saved as: output/mobile/netflix_com.png
# 48
# Screenshot saved as: output/desktop/whatsapp_net.png
# Screenshot saved as: output/mobile/whatsapp_net.png
# 49
# Screenshot saved as: output/desktop/pinterest_com.png
# Screenshot saved as: output/mobile/pinterest_com.png
# 50
# Screenshot saved as: output/desktop/digicert_com.png
# Screenshot saved as: output/mobile/digicert_com.png
# 51
# Screenshot saved as: output/desktop/yahoo_com.png
# Screenshot saved as: output/mobile/yahoo_com.png
# 52
# error
# error
# 53
# error
# error
# 54
# Screenshot saved as: output/desktop/appsflyersdk_com.png
# Screenshot saved as: output/mobile/appsflyersdk_com.png
# 55
# Screenshot saved as: output/desktop/adobe_com.png
# Screenshot saved as: output/mobile/adobe_com.png
# 56
# error
# error
# 57
# Screenshot saved as: output/desktop/goo_gl.png
# Screenshot saved as: output/mobile/goo_gl.png
# 58
# Screenshot saved as: output/desktop/vimeo_com.png
# Screenshot saved as: output/mobile/vimeo_com.png
# 59
# Screenshot saved as: output/desktop/windows_net.png
# Screenshot saved as: output/mobile/windows_net.png
# 60
# Screenshot saved as: output/desktop/spotify_com.png
# Screenshot saved as: output/mobile/spotify_com.png
# 61
# error
# error
# 62
# Screenshot saved as: output/desktop/skype_com.png
# Screenshot saved as: output/mobile/skype_com.png
# 63
# Screenshot saved as: output/desktop/tiktokv_com.png
# Screenshot saved as: output/mobile/tiktokv_com.png
# 64
# Screenshot saved as: output/desktop/whatsapp_com.png
# Screenshot saved as: output/mobile/whatsapp_com.png
# 65
# error
# error
# 66
# Screenshot saved as: output/desktop/bit_ly.png
# Screenshot saved as: output/mobile/bit_ly.png
# 67
# Screenshot saved as: output/desktop/google-analytics_com.png
# Screenshot saved as: output/mobile/google-analytics_com.png
# 68
# Screenshot saved as: output/desktop/msn_com.png
# Screenshot saved as: output/mobile/msn_com.png
# 69
# error
# error
# 70
# Screenshot saved as: output/desktop/wordpress_com.png
# Screenshot saved as: output/mobile/wordpress_com.png
# 71
# error
# error
# 72
# Screenshot saved as: output/desktop/cloudflare_net.png
# Screenshot saved as: output/mobile/cloudflare_net.png
# 73
# Screenshot saved as: output/desktop/zoom_us.png
# Screenshot saved as: output/mobile/zoom_us.png
# 74
# Screenshot saved as: output/desktop/ntp_org.png
# Screenshot saved as: output/mobile/ntp_org.png
# 75
# error
# error
# 76
# error
# error
# 77
# Screenshot saved as: output/desktop/nic_ru.png
# Screenshot saved as: output/mobile/nic_ru.png
# 78
# Screenshot saved as: output/desktop/tiktok_com.png
# Screenshot saved as: output/mobile/tiktok_com.png
# 79
# Screenshot saved as: output/desktop/office365_com.png
# Screenshot saved as: output/mobile/office365_com.png
# 80
# Screenshot saved as: output/desktop/gandi_net.png
# Screenshot saved as: output/mobile/gandi_net.png
# 81
# Screenshot saved as: output/desktop/qq_com.png
# Screenshot saved as: output/mobile/qq_com.png
# 82
# Screenshot saved as: output/desktop/yandex_net.png
# Screenshot saved as: output/mobile/yandex_net.png
# 83
# Screenshot saved as: output/desktop/roblox_com.png
# Screenshot saved as: output/mobile/roblox_com.png
# 84
# error
# error
# 85
# Screenshot saved as: output/desktop/blogspot_com.png
# Screenshot saved as: output/mobile/blogspot_com.png
# 86
# error
# error
# 87
# Screenshot saved as: output/desktop/mozilla_org.png
# Screenshot saved as: output/mobile/mozilla_org.png
# 88
# Screenshot saved as: output/desktop/cloudflare-dns_com.png
# Screenshot saved as: output/mobile/cloudflare-dns_com.png
# 89
# Screenshot saved as: output/desktop/x_com.png
# Screenshot saved as: output/mobile/x_com.png
# 90
# Screenshot saved as: output/desktop/reddit_com.png
# Screenshot saved as: output/mobile/reddit_com.png
# 91
# Screenshot saved as: output/desktop/opera_com.png
# Screenshot saved as: output/mobile/opera_com.png
# 92
# error
# error
# 93
# Screenshot saved as: output/desktop/googleadservices_com.png
# Screenshot saved as: output/mobile/googleadservices_com.png
# 94
# Screenshot saved as: output/desktop/unity3d_com.png
# Screenshot saved as: output/mobile/unity3d_com.png
# 95
# error
# error
# 96
# Screenshot saved as: output/desktop/samsung_com.png
# Screenshot saved as: output/mobile/samsung_com.png
# 97
# Screenshot saved as: output/desktop/baidu_com.png
# Screenshot saved as: output/mobile/baidu_com.png
# 98
# error
# error
# 99
# Screenshot saved as: output/desktop/europa_eu.png
# Screenshot saved as: output/mobile/europa_eu.png
# 100
# Screenshot saved as: output/desktop/intuit_com.png
# Screenshot saved as: output/mobile/intuit_com.png
# 101
# Screenshot saved as: output/desktop/snapchat_com.png
# Screenshot saved as: output/mobile/snapchat_com.png
# 102
# error
# error
# 103
# Screenshot saved as: output/desktop/mts_ru.png
# Screenshot saved as: output/mobile/mts_ru.png
# 104
# Screenshot saved as: output/desktop/amazon-adsystem_com.png
# Screenshot saved as: output/mobile/amazon-adsystem_com.png
# 105
# Screenshot saved as: output/desktop/googledomains_com.png
# Screenshot saved as: output/mobile/googledomains_com.png
# 106
# error
# error
# 107
# error
# error
# 108
# Screenshot saved as: output/desktop/wa_me.png
# Screenshot saved as: output/mobile/wa_me.png
# 109
# Screenshot saved as: output/desktop/t_me.png
# Screenshot saved as: output/mobile/t_me.png
# 110
# error
# error
# 111
# Screenshot saved as: output/desktop/outlook_com.png
# Screenshot saved as: output/mobile/outlook_com.png
# 112
# error
# error
# 113
# Screenshot saved as: output/desktop/nih_gov.png
# Screenshot saved as: output/mobile/nih_gov.png
# 114
# Screenshot saved as: output/desktop/vk_com.png

# %% [markdown]
# # Scraping the HTML and CSS code

# %%
def get_website_html(url, filepath_html, filepath_css, mobile=False):
    try:
        chrome_options = Options()
        chrome_options.add_argument("--headless=new")
        chrome_options.add_extension('extension/no-cookie.crx')

        if mobile:
            chrome_options.add_argument('--user-agent=Mozilla/5.0 (iPhone; CPU iPhone OS 17_7 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) CriOS/131.0.6778.134 Mobile/15E148 Safari/604.1')
            chrome_options.add_argument("--window-size=393,873")
        
        driver = webdriver.Chrome(options=chrome_options)
        driver.get("http://"+url)

        fileToWrite = open(filepath_html, "w")
        fileToWrite.write(driver.page_source)
        fileToWrite.close()

        styles = driver.execute_script("""
            let css = '';
            for (let sheet of document.styleSheets) {
                try {
                    for (let rule of sheet.cssRules) {
                        css += rule.cssText + '\\n';
                    }
                } catch (e) {
                    console.log('Cannot access stylesheet:', sheet.href);
                }
            }
            return css;
        """)

        with open(filepath_css, "w", encoding="utf-8") as file:
            file.write(styles)

    except Exception as e:
        print("error")
    finally:
        driver.quit()

get_website_html(df_url['url'][2],"output/output.html", "output/output.css")

# %%
for i in range (1010):
    filepath_desktop_html = 'output/html/'+df_url['url'][i].replace(".", "_")+'_desktop'+'.html'
    filepath_mobile_html = 'output/html/'+df_url['url'][i].replace(".", "_")+'_mobile'+'.html'

    filepath_desktop_css = 'output/css/'+df_url['url'][i].replace(".", "_")+'_desktop'+'.css'
    filepath_mobile_css = 'output/css/'+df_url['url'][i].replace(".", "_")+'_mobile'+'.css'
    get_website_html(df_url['url'][i], filepath_desktop_html, filepath_desktop_css)
    get_website_html(df_url['url'][i], filepath_mobile_html, filepath_mobile_css, mobile=True)
    print(i)
# Out:
# 0
# 1
